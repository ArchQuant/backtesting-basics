# %% [markdown]
# # SMA backtesting

# %%
from backtesters import SMAVectorBacktester

# %%
smabt = SMAVectorBacktester('EUR=', 42, 252, '2010-1-1', '2019-12-31')

# %%
type(smabt)
# Out:
# backtesters.SMAVectorBacktester.SMAVectorBacktester

# %%
smabt.run_strategy()
# Out:
# (1.29, 0.45)

# %%
# %%time
smabt.optimize_parameters((30, 50, 2),
                          (200, 300, 2))
# Out:
# Wall time: 2 s
# (array([ 48., 238.]), 1.5)

# %%
smabt.plot_results()
